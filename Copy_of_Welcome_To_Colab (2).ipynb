# %% [markdown]
# # Functions: Assignment 3

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
# -> Function are the block code that used to perform a specific task,function makes the code neat,clean ,organized and it saves lots of time.
#
# -> Method is a function that is defined inside the class and called by the object using(.) symbol.

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
#
# -> A parameter is a variable listed inside the parentheses when you define a function.
#
# -> An argument is the actual value you pass into the function when you call it.
#
# example:

# %%
''' a and b are parameters'''
''' 2 and 3 are Arguments'''
def func(a,b):
  return a+b
func(2,3)
# Out:
# 5

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
#
# -> 1.  using def keywords: One way to define the function is by using def keyword and we can call it by writing the name of the function with the parentheses.
#  example:  def func():
#               print("Naman is brave")
#   2. using function with parameters: We can use function by using variables inside the functions.
#       example: def fun(a,b):
#                  print(a is not equal to b)
#
#   3. using return statement: we can use function with return statement.
#
#        example: def func(a,b)
#                    return a+b
#
#   4. using default argument: we can use function with default arguments inside the function. these are the arguments whose value is declared at the start. Default argument is followed by positional argument.
#
#        example: def func(b,a=0)
#                   return a+b
#
#   5. using keyword arguments: we can use function with keyword arguments these are arguments which take values during the function calling in the form of key value pair.
#
#        example:  def func(**kwargs):
#                   return kwargs
#
#   6. using varible length argument: we can use function with varible length argument these are the arguments which can take any amount of value during the function callling.
#
#            example:    def func(*args):
#                         return args
#
#   7. Using lambda function: we can use lambda to declare a function in which we use lambda keyword to define it followed by arguments and expression.
#
#
#             example : lambda x:x**2

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
#
# -> Return statment returns the value as it is.
#
# -> without using return statement the type of function becomes none.
#
# example:

# %%
def func(a,b):
  return a**b
func(2,3)
# Out:
# 8

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#
# -> iterators are object that are in ready state to be iterated.
#
#   on the other hand
#
# -> Iterator is any python object that is capable of returing its member at a time.

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
#
# -> generators functions are special type of functions that returns an iterator but instead of using return statement it used yield statement to return the value one at time.

# %%
def func(n):
  for i in range(n):
    yield i**2

pow=func(10)
next(pow)
# Out:
# 4

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#
# -> Advantages of generators over regular functions-:
#
# 1. Regular function calculates the value and return in one go since its returning in one go and memory usage will be more.
#
# 2. It will take a lot of execution time if there is lot of computation as all the computation will be done first then all the values will be returned in one go.
#
# 3. So by using generator funcition we can return an iterator by using yield statement we get the value one by one so it saves both memory and time.

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
#
# -> lambda function is also called Anonymous it is declared by using lambda keywords followed by Arguments and expression.
#
# -> A lambda function is used when you need a small, quick or simplified function especially when you don’t want to write a full def block.

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python.
#
# -> Map functiton executes a specified function for each item of an iterable.
#
# syntax: map(function,*iterable)
#
# example:

# %%
l1=[2,4,5,6,7,8]
list(map(lambda x:x**2,l1))
# Out:
# [4, 16, 25, 36, 49, 64]

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# -> map(): map funciton uses a specified function for each item of an iterable.
#
# -> reduce():reduce function takes 2 arguments and reduce a sequence to a single value.
#
# ->filter():filter it used to filter elements from an iterable based on some condition.

# %%
'''Map'''
l1=[2,4,5,6,7,8]
print(list(map(lambda x:x**2,l1)))
'''Reduce'''
from functools import reduce
print(reduce(lambda x,y:x+y,l1))

'''Filter'''
list(filter(lambda x:x%2==0,l1))
# Out:
# [4, 16, 25, 36, 49, 64]
# 32
# [2, 4, 6, 8]

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
# ![WhatsApp Image 2025-06-16 at 14.24.08_db363f23.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Practical Questions

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def final_sum(list1):
  return sum(list1)
def func(n):
  list1=[]
  for i in n:
    if i%2==0:
      list1.append(i)
  return final_sum(list1)
func([1,2,4,5,7,6,9,8])
# Out:
# 20

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
    return s[::-1]
reverse_string("Virat")
# Out:
# 'tariV'

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def func(n):
  l1=[]
  for i in n:
    if type(i)==int:
      i=i**2
      l1.append(i)
  return l1

func([2,4,5,6,7,"Naman"])
# Out:
# [4, 16, 25, 36, 49]

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def fun(n):
  if 1<=n<=200:
    if n <= 1:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False
    return True

  else:
    return "out of range"

fun(201)
# Out:
# 'out of range'

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
def fibonicci(n):
  a=0
  b=1
  list1=[]
  for i in range(n):
    list1.append(a)
    a,b=b,a+b
  return list1

f=iter(fibonicci(10))
next(f)

next(f)


next(f)
# Out:
# 1

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def func(n):
  if n==0:
    return 1
  else:
    for i in range(1,n+1):
      yield 2**i

f=func(5)
next(f)
next(f)
# Out:
# 4

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string

# %%
# Out:
# this is Naman
# this is Aarushi
# this is Saksham

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
l1=[(12,5,4),(3,7,9),(2,9,6),(8,6,12)]
sortedlist=sorted(l1,key=lambda x:x[1])
print(sortedlist)
# Out:
# [(12, 5, 4), (8, 6, 12), (3, 7, 9), (2, 9, 6)]

# %% [markdown]
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
temperature=[12,14,15,16]
list(map(lambda x:x*9/5+32,temperature))
# Out:
# [53.6, 57.2, 59.0, 60.8]

# %% [markdown]
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
s = "Naman"
vowels = 'aeiouAEIOU'

result = filter(lambda x: x not in vowels, s)


for x in result:
    print(x, end="")
# Out:
# Nmn

# %% [markdown]
# ![16.06.2025_18.35.13_REC.png](data:image/png;base64,...)

# %%
list1=[[34587,"Learning Python,Mark Lutz",4,40.95],[98762,"Programming Python,Mark Lutz",5,56.80],[77226,"Head first Python,Paul Barry",3,32.95],[88112,"Einfuhurung in Python3,Bernd Klein",3,24.99]]
book=list(map(lambda x:(x[0],x[2]*x[3]+ 10 if x[2]*x[3]<100 else x[2]*x[3]),list1))
print(book)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
